# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\spam_csv_delimited.csv",encoding_errors= 'replace')

# %%
df.head()
df.columns
df.sample(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17092\2496186485.py in ?()
#       1 df.head()
#       2 df.columns
#       3 df.sample(10)
# ----> 4 df["Text"].lower()
#
# ~\Saved Games\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df.shape

# %%
df.info()

# %%
df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.rename(columns={"v1":"Target","v2":"Text"},inplace=True)
df.sample(5)

# %%
from sklearn.preprocessing import LabelEncoder # Label encoder converts the values in form of numbers
encoder=LabelEncoder()

# %%
df["Target"]=encoder.fit_transform(df["Target"])

# %%
df.shape

# %%
df.tail()

# %%
df.head()

# %%
df.isnull().sum() # To check the missing values

# %% [markdown]
# # to check the duplicate vvalues

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(keep="first")

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS)

# %%
df["Target"].value_counts() # tells u the value of the input

# %% [markdown]
# #### says that 747 messages are spam

# %%
import matplotlib.pyplot as plot

# %%
plot.pie(df["Target"].value_counts(),labels=['ham','spam'] , autopct= "%0.2f")

# %%
import nltk

# %%
nltk.download("punkt")

# %%
df["num_of_char"]=df["Text"].apply(len)

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
df["num_of_words"]=df["Text"].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
df["random"]=df["Text"].apply(lambda x:len(x.split())) # just to show the differnece between split and tokenize

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
df.drop(columns=["random"])
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
#       num_of_words  num_of_sentences  \
# ...

# %%
df["num_of_sentences"]=df["Text"].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
df[["num_of_char","num_of_sentences","num_of_words"]].describe()
# Out:
#        num_of_char  num_of_sentences  num_of_words
# count  5572.000000       5572.000000   5572.000000
# mean     80.058327          1.997846     18.700826
# std      59.623937          1.522285     13.743217
# min       2.000000          1.000000      1.000000
# 25%      36.000000          1.000000      9.000000
# 50%      61.000000          2.000000     15.000000
# 75%     121.000000          2.000000     27.000000
# max     910.000000         38.000000    220.000000

# %%
def transform_text(text):
    text=text.lower() # making the text lower case
    text=nltk.word_tokenize(text) # converting the sentences into words
    y=[]
    for i in text: # removing the special charecter
        if i.isalnum():
            
            
            y.append(i)
            
    text=y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words("english") and i not in string.punctuation:  # Stopping words and punctuation
            y.append(i)
    
    text=y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i)) # Stemming
    
    
    return y

# %%
b="!"
transform_text(" saying that he is a peice of shit")
# Out:
# ['say', 'peic', 'shit']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chaka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words("english")
import string
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()
ps.stem("fucking")
# Out:
# 'fuck'

# %%
df["transformed text"]=df["Text"].apply(transform_text)

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
df
# Out:
#       Target                                               Text  num_of_char  \
# 0          0  Go until jurong point, crazy.. Available only ...          111
# 1          0                      Ok lar... Joking wif u oni...           29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3          0  U dun say so early hor... U c already then say...           49
# 4          0  Nah I don't think he goes to usf, he lives aro...           61
# ...      ...                                                ...          ...
# 5567       1  This is the 2nd time we have tried 2 contact u...          160
# 5568       0              Will �_ b going to esplanade fr home?           37
# 5569       0  Pity, * was in mood for that. So...any other s...           57
# 5570       0  The guy did some bitching but I acted like i'd...          125
# 5571       0                         Rofl. Its true to its name           26
#
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df[df["Target"]==0]["num_of_char"])
sns.histplot(df[df["Target"]==1]["num_of_char"],color="red")
# Out:
# <Axes: xlabel='num_of_char', ylabel='Count'>

# %%
sns.pairplot(df,hue="Target")
